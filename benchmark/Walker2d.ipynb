# %%
import torch.nn as nn

# %%
nn.ReLU.__name__
# Out:
# 'ReLU'

# %%
from utils import plot_logs
# Out:
# /home/quazar/anaconda3/envs/pytorch_source/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
plot_logs(log_dir='./logs/Walker2d-v1/', tags=['tanh-0.0003-dna-ns-sr-gamma0.99-gae0.98-spb2048-epb-1',
                                               'tanh-0.001-dna-ns-sr-gamma0.99-gae0.98-spb2048-epb-1',
                                               'tanh-0.001-dna-ns-sr-gamma0.99-gae0.95-spb2048-epb-1',                                              
                                               'relu-0.001-na-ns-sr-gamma0.99-gae0.95-spb2048-epb-1'])
# Out:
# Reading: logs/Walker2d-v1/tanh-0.0003-dna-ns-sr-gamma0.99-gae0.98-spb2048-epb-1-v0/events.out.tfevents.1524559144.quazar-GA-78LMT-USB3
# Reading: logs/Walker2d-v1/tanh-0.001-dna-ns-sr-gamma0.99-gae0.98-spb2048-epb-1-v0/events.out.tfevents.1524551443.quazar-GA-78LMT-USB3
# Reading: logs/Walker2d-v1/tanh-0.001-dna-ns-sr-gamma0.99-gae0.95-spb2048-epb-1-v0/events.out.tfevents.1524557494.quazar-GA-78LMT-USB3
# Reading: logs/Walker2d-v1/relu-0.001-na-ns-sr-gamma0.99-gae0.95-spb2048-epb-1-v0/events.out.tfevents.1524554398.quazar-GA-78LMT-USB3
