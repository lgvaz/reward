# %%
from IPython.display import Image
from utils import plot_logs
# Out:
# /home/quazar/anaconda3/envs/pytorch_source/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Paper Results

# %% [markdown]
# ### [PPO](arxiv.org/pdf/1707.06347.pdf)

# %%
Image('imgs/ppo/halfcheetah_paper.png')

# %% [markdown]
# ## Experiment Results

# %%
plot_logs(log_dir='./logs/HalfCheetah-v2/', tags=['PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5'])
# Out:
# Reading: logs/HalfCheetah-v2/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t1/events.out.tfevents.1524621724.quazar-GA-78LMT-USB3
# Reading: logs/HalfCheetah-v2/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t3/events.out.tfevents.1524621740.quazar-GA-78LMT-USB3
# Reading: logs/HalfCheetah-v2/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t0/events.out.tfevents.1524619654.quazar-GA-78LMT-USB3
# Reading: logs/HalfCheetah-v2/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t2/events.out.tfevents.1524619654.quazar-GA-78LMT-USB3

# %%
plot_logs(log_dir='./logs/RoboschoolHalfCheetah-v1/', tags=['PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5',
                                                            'PPO-Tanh-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5'])
# Out:
# Reading: logs/RoboschoolHalfCheetah-v1/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t1/events.out.tfevents.1524598682.quazar-GA-78LMT-USB3
# Reading: logs/RoboschoolHalfCheetah-v1/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t3/events.out.tfevents.1524602178.quazar-GA-78LMT-USB3
# Reading: logs/RoboschoolHalfCheetah-v1/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t0/events.out.tfevents.1524596833.quazar-GA-78LMT-USB3
# Reading: logs/RoboschoolHalfCheetah-v1/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t2/events.out.tfevents.1524600274.quazar-GA-78LMT-USB3
# ...
