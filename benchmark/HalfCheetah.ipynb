# %%
from IPython.display import Image
from utils import plot_logs
# Out:
# /home/quazar/anaconda3/envs/pytorch_source/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Paper Results

# %% [markdown]
# ### [PPO](arxiv.org/pdf/1707.06347.pdf)

# %%
Image('imgs/ppo/halfcheetah_paper.png')

# %% [markdown]
# ## Experiment Results

# %% [markdown]
# ## Best Results

# %%
# The first tag is the common best for Hopper, HalfCheetah and Walker
plot_logs(log_dir='./logs/HalfCheetah-v2/', tags=[
    'PPO-10epochvt6-ms1000000.0-spb2048-ReLU-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgnNone',
    'PPO-10epochvt6-ms1000000.0-spb2048-ReLU-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001)-vop(lr0.001)-cgnNone',
    'PPO-10epochvt6-ms1000000.0-spb2048-ReLU-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001)-vop(lr0.001)-cgn1.0',
    'PPO-10epochvReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5'
])

# %% [markdown]
# ## All Results

# %%
plot_logs(log_dir='./logs/HalfCheetah-v2/', tags=['PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5',
                                                  'PPO-10epochvReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5',
                                                  'PPO-10epochv-mseReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5',
                                                  'PPO-10epochvTanh-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5',
                                                  'PPO-10epochvReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.0003_eps1e-05)-vop(lr0.0003_eps1e-05)-cgn0.5',
                                                  'PPO-10epochvTanh-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.0003_eps1e-05)-vop(lr0.0003_eps1e-05)-cgn0.5',
                                                  'PPO-10epochvReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.98)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-',
                                                  'PPO-10epochvt6-ms1000000.0-spb2048-Tanh-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgnNone',
                                                  'PPO-10epochvt6-ms1000000.0-spb2048-ReLU-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgnNone',
                                                  'PPO-10epochvt6-ms1000000.0-spb2048-ReLU-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001)-vop(lr0.001)-cgn1.0',
                                                  'PPO-10epochvt6-ms1000000.0-spb2048-ReLU-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001)-vop(lr0.001)-cgnNone',
                                                  'PPO-10epochvt6-ms1000000.0-spb2048-ReLU-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.0003_eps1e-05)-vop(lr0.0003_eps1e-05)-cgnNone',
                                                  'PPO-10epochvt6-ms1000000.0-spb2048-Tanh-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001)-vop(lr0.001)-cgn1.0',
                                                  'PPO-10epochvt6-ms1000000.0-spb2048-Tanh-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001)-vop(lr0.001)-cgnNone',
                                                  'PPO-10epochvt6-ms1000000.0-spb2048-Tanh-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.0003_eps1e-05)-vop(lr0.0003_eps1e-05)-cgnNone'])
