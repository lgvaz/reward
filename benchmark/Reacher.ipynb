# %%
from IPython.display import Image
from utils import plot_logs
# Out:
# /home/quazar/anaconda3/envs/pytorch_source/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Paper Results

# %% [markdown]
# ### [PPO](arxiv.org/pdf/1707.06347.pdf)

# %%
Image('imgs/ppo/reacher_paper.png')

# %% [markdown]
# ## Experiment Results

# %%
plot_logs(log_dir='./logs/Reacher-v2/', tags=['PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5'])
# Out:
# Reading: logs/Reacher-v2/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t1/events.out.tfevents.1524625726.quazar-GA-78LMT-USB3
# Reading: logs/Reacher-v2/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t3/events.out.tfevents.1524628304.quazar-GA-78LMT-USB3
# Reading: logs/Reacher-v2/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t0/events.out.tfevents.1524624004.quazar-GA-78LMT-USB3
# Reading: logs/Reacher-v2/PPO-ReLU-ms1000000.0-spb2048-epb-1-na-ns-sr-GAE(g0.99_gl0.95)-pop(lr0.001_eps1e-05)-vop(lr0.001_eps1e-05)-cgn0.5-t2/events.out.tfevents.1524626708.quazar-GA-78LMT-USB3
