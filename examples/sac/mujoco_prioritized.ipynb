# %%
import pdb
import gym
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import reward as rw
import reward.utils as U
# Out:
# /home/quazar/anaconda3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
ENV = 'InvertedDoublePendulum-v2'
LOG_DIR = 'logs/doublependulum/repar-prioritized-schedule-v1-0'
REPAR = True
REWARD_SCALE = 1.
CLIP_GRAD = float('inf')
GAMMA = 0.99
TARGET_UP_WEIGHT = 0.01
BATCH_SIZE = 256
MAX_STEPS = 80000
LOG_FREQ = 1000
REPLAY_BUFFER_MAXLEN = 80000

# %%
pr_factor = 0.7
is_factor = U.schedules.linear_schedule(.4, 1, final_step=MAX_STEPS)

# %%
use_cuda = torch.cuda.is_available()
device   = torch.device("cuda" if use_cuda else "cpu")

# %%
env = rw.env.GymEnv(ENV)
env = rw.env.wrappers.ActionBound(env)
runner = rw.runner.SingleRunner(env)
batcher = rw.batcher.PrReplayBatcher(
    runner=runner,
    batch_size=256,
    replay_buffer_maxlen=REPLAY_BUFFER_MAXLEN,
    learning_freq=1,
    grad_steps_per_batch=1,
    pr_factor=pr_factor,
    is_factor=is_factor,
    transforms=[
#         rw.batcher.transforms.StateRunNorm(),        
    ],
)

state_features = batcher.get_state_info().shape[0]
num_actions = batcher.get_action_info().shape[0]
# Out:
# Choosing the latest nvidia driver: /usr/lib/nvidia-390, among ['/usr/lib/nvidia-375', '/usr/lib/nvidia-390']
# Choosing the latest nvidia driver: /usr/lib/nvidia-390, among ['/usr/lib/nvidia-375', '/usr/lib/nvidia-390']
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
class PolicyNN(nn.Module):
    def __init__(self, num_inputs, num_outputs, hidden_units=256,
                 activation=nn.ReLU, log_std_range=(-20, 2)):
        super().__init__()
        self.log_std_range = log_std_range
        
        layers = []
        layers += [nn.Linear(num_inputs, hidden_units), activation()]
        layers += [nn.Linear(hidden_units, hidden_units), activation()]
        self.layers = nn.Sequential(*layers)
        
        self.mean = nn.Linear(hidden_units, num_outputs)
        self.mean.weight.data.uniform_(-3e-3, 3e-3)
        self.mean.bias.data.uniform_(-3e-3, 3e-3)
        
        self.log_std = nn.Linear(hidden_units, num_outputs)
        self.log_std.weight.data.uniform_(-3e-3, 3e-3)
        self.log_std.bias.data.uniform_(-3e-3, 3e-3)
        
    def forward(self, x):
        x = self.layers(x)
        mean = self.mean(x)
        log_std = self.log_std(x).clamp(*self.log_std_range)
        return mean, log_std

# %%
class ValueNN(nn.Module):
    def __init__(self, num_inputs, hidden_units=256, activation=nn.ReLU):
        super().__init__()
        
        layers = []
        layers += [nn.Linear(num_inputs, hidden_units), activation()]
        layers += [nn.Linear(hidden_units, hidden_units), activation()]
        final_layer = nn.Linear(hidden_units, 1)
        final_layer.weight.data.uniform_(-3e-3, 3e-3)
        final_layer.bias.data.uniform_(-3e-3, 3e-3)
        layers += [final_layer]
        
        self.layers = nn.Sequential(*layers)
        
    def forward(self, x):
        return self.layers(x)

# %%
class QValueNN(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_units=256, activation=nn.ReLU):
        super().__init__()
        
        layers = []
        layers += [nn.Linear(num_inputs + num_actions, hidden_units), activation()]
        layers += [nn.Linear(hidden_units, hidden_units), activation()]
        final_layer = nn.Linear(hidden_units, 1)
        final_layer.weight.data.uniform_(-3e-3, 3e-3)
        final_layer.bias.data.uniform_(-3e-3, 3e-3)
        layers += [final_layer]
        
        self.layers = nn.Sequential(*layers)
        
    def forward(self, x):
        state, action = x
        x = torch.cat([state, action], dim=1)
        return self.layers(x)

# %%
class TanhNormalPolicy(rw.policy.BasePolicy):
    def create_dist(self, state):
        parameters = self.nn(state)
        mean, log_std = parameters
        return rw.distributions.TanhNormal(loc=mean, scale=log_std.exp())

    def get_action(self, state, step):
        dist = self.create_dist(state=state)
        action = U.to_np(dist.sample())
        assert not np.isnan(action).any()
        return action

# %%
p_nn = PolicyNN(num_inputs=state_features, num_outputs=num_actions).to(device)
v_nn = ValueNN(num_inputs=state_features).to(device)
v_nn_target = ValueNN(num_inputs=state_features).to(device).eval()
q1_nn = QValueNN(num_inputs=state_features, num_actions=num_actions).to(device)
q2_nn = QValueNN(num_inputs=state_features, num_actions=num_actions).to(device)

# %%
U.copy_weights(from_nn=v_nn, to_nn=v_nn_target, weight=1.)

# %%
policy = TanhNormalPolicy(nn=p_nn)

# %%
p_opt = torch.optim.Adam(p_nn.parameters(), lr=3e-4)
v_opt = torch.optim.Adam(v_nn.parameters(), lr=3e-4)
q1_opt = torch.optim.Adam(q1_nn.parameters(), lr=3e-4)
q2_opt = torch.optim.Adam(q2_nn.parameters(), lr=3e-4)

# %%
logger = U.Logger(LOG_DIR)
# Out:
# Writing logs to: logs/doublependulum/repar-prioritized-schedule-v1-0

# %%
batcher.populate(n=1000, act_fn=policy.get_action)
# Out:
# Populating Replay Buffer...
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
for batch in batcher.get_batches(MAX_STEPS, policy.get_action):
    batch = batch.to_tensor().concat_batch()
    idx = U.to_np(batch.idx).astype('int')

    ##### Calculate losses ######
    q1_batch = q1_nn((batch.state_t, batch.action))
    q2_batch = q2_nn((batch.state_t, batch.action))
    v_batch = v_nn(batch.state_t)

    dist = policy.create_dist(batch.state_t)
    if REPAR:
        action, pre_tanh_action = dist.rsample_with_pre()
    else:
        action, pre_tanh_action = dist.sample_with_pre()
    log_prob = dist.log_prob_pre(pre_tanh_action).sum(-1, keepdim=True)
    log_prob /= float(REWARD_SCALE)

    # Q loss
    v_target_tp1 = v_nn_target(batch.state_tp1)
    q_t_next = U.estimators.td_target(rewards=batch.reward, dones=batch.done,
                                         v_tp1=v_target_tp1, gamma=GAMMA)
    # Weighted TD error                                
    is_weight = U.to_tensor(batcher.get_is_weight(idx=idx))
    td1_error = is_weight * (q1_batch - q_t_next.detach())
    td2_error = is_weight * (q2_batch - q_t_next.detach())                             
    q1_loss = td1_error.pow(2).mean()
    q2_loss = td2_error.pow(2).mean()

    # V loss    
    q1_new_t = q1_nn((batch.state_t, action))
    q2_new_t = q2_nn((batch.state_t, action))
    q_new_t = torch.min(q1_new_t, q2_new_t)
    next_value = q_new_t - log_prob
    v_loss = F.mse_loss(v_batch, next_value.detach())

    # Policy loss    
    if REPAR:        
        p_loss = (log_prob - q_new_t).mean()
    else:
        next_log_prob = q_new_t - v_batch
        p_loss = (log_prob * (log_prob - next_log_prob).detach()).mean()
    # Policy regularization losses
    mean_loss = 1e-3 * dist.loc.pow(2).mean()
    log_std_loss = 1e-3 * dist.scale.log().pow(2).mean()
    pre_tanh_loss = 0 * pre_tanh_action.pow(2).sum(1).mean()
    # Combine all losses
    p_loss += mean_loss + log_std_loss + pre_tanh_loss

    ###### Optimize ######
    q1_opt.zero_grad()
    q1_loss.backward()
#     torch.nn.utils.clip_grad_norm_(q1_nn.parameters(), CLIP_GRAD)
    q1_grad = U.mean_grad(q1_nn)
    q1_opt.step()

    q2_opt.zero_grad()
    q2_loss.backward()
#     torch.nn.utils.clip_grad_norm_(q2_nn.parameters(), CLIP_GRAD)
    q2_grad = U.mean_grad(q2_nn)
    q2_opt.step()

    v_opt.zero_grad()
    v_loss.backward()
#     torch.nn.utils.clip_grad_norm_(v_nn.parameters(), CLIP_GRAD)
    v_grad = U.mean_grad(v_nn)
    v_opt.step()

    p_opt.zero_grad()
    p_loss.backward()
#     torch.nn.utils.clip_grad_norm_(p_nn.parameters(), CLIP_GRAD)
    p_grad = U.mean_grad(p_nn)
    p_opt.step()

    ###### Update target value network ######
    U.copy_weights(from_nn=v_nn, to_nn=v_nn_target, weight=TARGET_UP_WEIGHT)
    
    ###### Update replay batcher priorities #######    
    td_error = U.to_np((q_new_t - q_t_next).abs())
    batcher.update_pr(idx=idx, pr=td_error)

    ###### Write logs ######
    if batcher.num_steps % LOG_FREQ == 0 and batcher.runner.rewards:
        batcher.write_logs(logger)    

        logger.add_log('policy/loss', p_loss)
        logger.add_log('v/loss', v_loss)
        logger.add_log('q1/loss', q1_loss)
        logger.add_log('q2/loss', q2_loss)

        logger.add_log('policy/grad', p_grad)
        logger.add_log('v/grad', v_grad)
        logger.add_log('q1/grad', q1_grad)
        logger.add_log('q2/grad', q2_grad)

        logger.add_histogram('policy/log_prob', log_prob)
        logger.add_histogram('policy/mean', dist.loc)
        logger.add_histogram('policy/std', dist.scale.exp())
        logger.add_histogram('v/value', v_batch)
        logger.add_histogram('q1/value', q1_batch)
        logger.add_histogram('q2/value', q2_batch)

        logger.log(step=batcher.num_steps)
# Out:
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=80000), HTML(value='')), layout=Layout(display='inline-flex', flex_flow='row wrap', width='100%'))
#                          Step 2000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                              |  61.09
# Env/Length/Episode (New)                              |   6.70
# Env/Reward/Episode (Last 50)                          | 108.81
# Env/Length/Episode (Last 50)                          |  11.80
# policy/loss                                           | -51.02
# v/loss                                                |   2.39
# q1/loss                                               |   4.49
# q2/loss                                               |   4.24
# policy/grad                                           |  -0.02
# v/grad                                                |  -0.45
# q1/grad                                               |   0.01
# q2/grad                                               |  -0.01
# --------------------------------------------------------------
#
#                          Step 3000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                              | 175.18
# Env/Length/Episode (New)                              |  18.90
# Env/Reward/Episode (Last 50)                          | 177.00
# Env/Length/Episode (Last 50)                          |  19.10
# policy/loss                                           | -92.00
# v/loss                                                |   6.16
# q1/loss                                               |   3.07
# q2/loss                                               |   3.18
# policy/grad                                           |  -0.31
# v/grad                                                |   0.23
# q1/grad                                               |   0.02
# q2/grad                                               |   0.03
# --------------------------------------------------------------
#
#                          Step 4000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             |  263.41
# Env/Length/Episode (New)                             |   28.35
# Env/Reward/Episode (Last 50)                         |  240.50
# Env/Length/Episode (Last 50)                         |   25.90
# policy/loss                                          | -124.26
# v/loss                                               |   13.15
# q1/loss                                              |    3.33
# q2/loss                                              |    3.67
# policy/grad                                          |   -0.18
# v/grad                                               |    0.47
# q1/grad                                              |   -0.08
# q2/grad                                              |   -0.10
# --------------------------------------------------------------
#
#                          Step 5000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             |  356.23
# Env/Length/Episode (New)                             |   38.31
# Env/Reward/Episode (Last 50)                         |  319.81
# Env/Length/Episode (Last 50)                         |   34.40
# policy/loss                                          | -161.66
# v/loss                                               |   17.36
# q1/loss                                              |    2.46
# q2/loss                                              |    2.24
# policy/grad                                          |    0.49
# v/grad                                               |   -0.31
# q1/grad                                              |   -0.03
# q2/grad                                              |   -0.00
# --------------------------------------------------------------
#
#                          Step 6000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             |  577.45
# Env/Length/Episode (New)                             |   61.94
# Env/Reward/Episode (Last 50)                         |  424.53
# Env/Length/Episode (Last 50)                         |   45.60
# policy/loss                                          | -197.30
# v/loss                                               |   18.36
# q1/loss                                              |    1.75
# q2/loss                                              |    1.53
# policy/grad                                          |    1.27
# v/grad                                               |    0.05
# q1/grad                                              |   -0.03
# q2/grad                                              |   -0.00
# --------------------------------------------------------------
#
#                          Step 7000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             |  597.64
# Env/Length/Episode (New)                             |   64.10
# Env/Reward/Episode (Last 50)                         |  469.23
# Env/Length/Episode (Last 50)                         |   50.38
# policy/loss                                          | -233.54
# v/loss                                               |   50.07
# q1/loss                                              |    1.91
# q2/loss                                              |    2.06
# policy/grad                                          |   -0.81
# v/grad                                               |    0.54
# q1/grad                                              |   -0.01
# q2/grad                                              |   -0.01
# --------------------------------------------------------------
#
#                          Step 8000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 3792.63
# Env/Length/Episode (New)                             |  405.50
# Env/Reward/Episode (Last 50)                         |  610.36
# Env/Length/Episode (Last 50)                         |   65.46
# policy/loss                                          | -258.74
# v/loss                                               |   28.40
# q1/loss                                              |    2.34
# q2/loss                                              |    2.54
# policy/grad                                          |   -0.58
# v/grad                                               |    0.54
# q1/grad                                              |    0.01
# q2/grad                                              |   -0.02
# --------------------------------------------------------------
#
#                          Step 9000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 2095.99
# Env/Length/Episode (New)                             |  224.20
# Env/Reward/Episode (Last 50)                         |  788.17
# Env/Length/Episode (Last 50)                         |   84.46
# policy/loss                                          | -256.94
# v/loss                                               |   37.70
# q1/loss                                              |    2.03
# q2/loss                                              |    1.84
# policy/grad                                          |    0.15
# v/grad                                               |   -0.60
# q1/grad                                              |   -0.05
# q2/grad                                              |    0.01
# --------------------------------------------------------------
#
#                          Step 10000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 1997.50
# Env/Length/Episode (New)                             |  213.67
# Env/Reward/Episode (Last 50)                         |  896.74
# Env/Length/Episode (Last 50)                         |   96.06
# policy/loss                                          | -290.07
# v/loss                                               |   26.06
# q1/loss                                              |    2.67
# q2/loss                                              |    2.73
# policy/grad                                          |    0.52
# v/grad                                               |    0.14
# q1/grad                                              |   -0.06
# q2/grad                                              |   -0.00
# --------------------------------------------------------------
#                          Step 11000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9359.00
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 1075.35
# Env/Length/Episode (Last 50)                         |  115.14
# policy/loss                                          | -291.91
# v/loss                                               |   27.92
# q1/loss                                              |    3.51
# q2/loss                                              |    3.70
# policy/grad                                          |   -1.07
# v/grad                                               |   -0.87
# q1/grad                                              |    0.15
# q2/grad                                              |    0.00
# --------------------------------------------------------------
#
#                          Step 12000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 3225.16
# Env/Length/Episode (New)                             |  344.80
# Env/Reward/Episode (Last 50)                         | 1353.56
# Env/Length/Episode (Last 50)                         |  144.86
# policy/loss                                          | -309.70
# v/loss                                               |   45.77
# q1/loss                                              |   71.65
# q2/loss                                              |   71.12
# policy/grad                                          |    1.26
# v/grad                                               |   -0.91
# q1/grad                                              |   -0.25
# q2/grad                                              |   -0.20
# --------------------------------------------------------------
#
#                          Step 13000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 1140.52
# Env/Length/Episode (New)                             |  122.11
# Env/Reward/Episode (Last 50)                         | 1485.72
# Env/Length/Episode (Last 50)                         |  158.98
# policy/loss                                          | -301.67
# v/loss                                               |   31.76
# q1/loss                                              |    4.05
# q2/loss                                              |    4.45
# policy/grad                                          |    0.27
# v/grad                                               |   -0.75
# q1/grad                                              |    0.24
# q2/grad                                              |    0.19
# --------------------------------------------------------------
#
#                          Step 14000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 1778.16
# Env/Length/Episode (New)                             |  190.25
# Env/Reward/Episode (Last 50)                         | 1594.47
# Env/Length/Episode (Last 50)                         |  170.60
# policy/loss                                          | -280.92
# v/loss                                               |   28.58
# q1/loss                                              |   93.80
# q2/loss                                              |   94.62
# policy/grad                                          |   -0.63
# v/grad                                               |   -0.51
# q1/grad                                              |   -0.21
# q2/grad                                              |   -0.19
# --------------------------------------------------------------
#
#                          Step 15000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9356.97
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 1775.85
# Env/Length/Episode (Last 50)                         |  189.98
# policy/loss                                          | -279.81
# v/loss                                               |   30.06
# q1/loss                                              |   97.36
# q2/loss                                              |   98.17
# policy/grad                                          |   -0.02
# v/grad                                               |   -0.54
# q1/grad                                              |   -0.27
# q2/grad                                              |   -0.15
# --------------------------------------------------------------
#
#                          Step 16000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9357.77
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 1947.89
# Env/Length/Episode (Last 50)                         |  208.36
# policy/loss                                          | -293.64
# v/loss                                               |   31.00
# q1/loss                                              |   97.00
# q2/loss                                              |   97.86
# policy/grad                                          |    1.44
# v/grad                                               |   -0.08
# q1/grad                                              |   -0.09
# q2/grad                                              |    0.01
# --------------------------------------------------------------
#
#                          Step 17000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9358.42
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 2127.79
# Env/Length/Episode (Last 50)                         |  227.58
# policy/loss                                          | -304.92
# v/loss                                               |   34.56
# q1/loss                                              |   40.40
# q2/loss                                              |   40.83
# policy/grad                                          |   -2.31
# v/grad                                               |    0.51
# q1/grad                                              |   -0.10
# q2/grad                                              |   -0.04
# --------------------------------------------------------------
#
#                          Step 18000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9358.33
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 2303.97
# Env/Length/Episode (Last 50)                         |  246.40
# policy/loss                                          | -298.87
# v/loss                                               |   36.71
# q1/loss                                              |   42.91
# q2/loss                                              |   42.93
# policy/grad                                          |   -0.91
# v/grad                                               |   -0.41
# q1/grad                                              |    0.04
# q2/grad                                              |    0.02
# --------------------------------------------------------------
#
#                          Step 19000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9358.05
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 2477.88
# Env/Length/Episode (Last 50)                         |  264.98
# policy/loss                                          | -299.00
# v/loss                                               |   66.84
# q1/loss                                              |   63.97
# q2/loss                                              |   64.46
# policy/grad                                          |   -1.61
# v/grad                                               |   -1.94
# q1/grad                                              |   -0.35
# q2/grad                                              |   -0.16
# --------------------------------------------------------------
#                          Step 20000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9357.45
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 2655.72
# Env/Length/Episode (Last 50)                         |  283.98
# policy/loss                                          | -305.38
# v/loss                                               |   73.13
# q1/loss                                              |   26.24
# q2/loss                                              |   26.13
# policy/grad                                          |    0.06
# v/grad                                               |   -1.59
# q1/grad                                              |    0.13
# q2/grad                                              |    0.13
# --------------------------------------------------------------
#
#                          Step 21000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9357.66
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 2831.68
# Env/Length/Episode (Last 50)                         |  302.78
# policy/loss                                          | -288.24
# v/loss                                               |   71.38
# q1/loss                                              |   18.60
# q2/loss                                              |   18.67
# policy/grad                                          |    0.78
# v/grad                                               |   -0.51
# q1/grad                                              |    0.28
# q2/grad                                              |    0.11
# --------------------------------------------------------------
