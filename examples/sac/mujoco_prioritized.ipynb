# %%
import pdb
import gym
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import reward as rw
import reward.utils as U
# Out:
# /home/quazar/anaconda3/envs/torchrl_up/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
ENV = 'InvertedDoublePendulum-v2'
LOG_DIR = 'logs/doublependulum/repar-prioritized-schedule-v0-1'
REPAR = True
REWARD_SCALE = 1.
CLIP_GRAD = float('inf')
GAMMA = 0.99
TARGET_UP_WEIGHT = 0.01
BATCH_SIZE = 256
MAX_STEPS = 80000
LOG_FREQ = 1000
REPLAY_BUFFER_MAXLEN = 80000

# %%
pr_weight = U.schedules.linear_schedule(.7, .1, final_step=MAX_STEPS)

# %%
use_cuda = torch.cuda.is_available()
device   = torch.device("cuda" if use_cuda else "cpu")

# %%
env = rw.envs.GymEnv(ENV)
env = rw.envs.wrappers.ActionBound(env)
runner = rw.runners.SingleRunner(env)
batcher = rw.batchers.PrReplayBatcher(
    runner=runner,
    batch_size=256,
    replay_buffer_maxlen=REPLAY_BUFFER_MAXLEN,
    learning_freq=1,
    grad_steps_per_batch=1,
    pr_weight=pr_weight,
    transforms=[
#         rw.batchers.transforms.StateRunNorm(),        
    ],
)

state_features = batcher.get_state_info().shape[0]
num_actions = batcher.get_action_info().shape[0]
# Out:
# Choosing the latest nvidia driver: /usr/lib/nvidia-390, among ['/usr/lib/nvidia-375', '/usr/lib/nvidia-390']
# Choosing the latest nvidia driver: /usr/lib/nvidia-390, among ['/usr/lib/nvidia-375', '/usr/lib/nvidia-390']
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
class PolicyNN(nn.Module):
    def __init__(self, num_inputs, num_outputs, hidden_units=256,
                 activation=nn.ReLU, log_std_range=(-20, 2)):
        super().__init__()
        self.log_std_range = log_std_range
        
        layers = []
        layers += [nn.Linear(num_inputs, hidden_units), activation()]
        layers += [nn.Linear(hidden_units, hidden_units), activation()]
        self.layers = nn.Sequential(*layers)
        
        self.mean = nn.Linear(hidden_units, num_outputs)
        self.mean.weight.data.uniform_(-3e-3, 3e-3)
        self.mean.bias.data.uniform_(-3e-3, 3e-3)
        
        self.log_std = nn.Linear(hidden_units, num_outputs)
        self.log_std.weight.data.uniform_(-3e-3, 3e-3)
        self.log_std.bias.data.uniform_(-3e-3, 3e-3)
        
    def forward(self, x):
        x = self.layers(x)
        mean = self.mean(x)
        log_std = self.log_std(x).clamp(*self.log_std_range)
        return mean, log_std

# %%
class ValueNN(nn.Module):
    def __init__(self, num_inputs, hidden_units=256, activation=nn.ReLU):
        super().__init__()
        
        layers = []
        layers += [nn.Linear(num_inputs, hidden_units), activation()]
        layers += [nn.Linear(hidden_units, hidden_units), activation()]
        final_layer = nn.Linear(hidden_units, 1)
        final_layer.weight.data.uniform_(-3e-3, 3e-3)
        final_layer.bias.data.uniform_(-3e-3, 3e-3)
        layers += [final_layer]
        
        self.layers = nn.Sequential(*layers)
        
    def forward(self, x):
        return self.layers(x)

# %%
class QValueNN(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_units=256, activation=nn.ReLU):
        super().__init__()
        
        layers = []
        layers += [nn.Linear(num_inputs + num_actions, hidden_units), activation()]
        layers += [nn.Linear(hidden_units, hidden_units), activation()]
        final_layer = nn.Linear(hidden_units, 1)
        final_layer.weight.data.uniform_(-3e-3, 3e-3)
        final_layer.bias.data.uniform_(-3e-3, 3e-3)
        layers += [final_layer]
        
        self.layers = nn.Sequential(*layers)
        
    def forward(self, x):
        state, action = x
        x = torch.cat([state, action], dim=1)
        return self.layers(x)

# %%
class TanhNormalPolicy(rw.policy.BasePolicy):
    def create_dist(self, state):
        parameters = self.nn(state)
        mean, log_std = parameters
        return rw.distributions.TanhNormal(loc=mean, scale=log_std.exp())

    def get_action(self, state, step):
        dist = self.create_dist(state=state)
        action = U.to_np(dist.sample())
        assert not np.isnan(action).any()
        return action

# %%
p_nn = PolicyNN(num_inputs=state_features, num_outputs=num_actions).to(device)
v_nn = ValueNN(num_inputs=state_features).to(device)
v_nn_target = ValueNN(num_inputs=state_features).to(device).eval()
q1_nn = QValueNN(num_inputs=state_features, num_actions=num_actions).to(device)
q2_nn = QValueNN(num_inputs=state_features, num_actions=num_actions).to(device)

# %%
U.copy_weights(from_nn=v_nn, to_nn=v_nn_target, weight=1.)

# %%
policy = TanhNormalPolicy(nn=p_nn)

# %%
p_opt = torch.optim.Adam(p_nn.parameters(), lr=3e-4)
v_opt = torch.optim.Adam(v_nn.parameters(), lr=3e-4)
q1_opt = torch.optim.Adam(q1_nn.parameters(), lr=3e-4)
q2_opt = torch.optim.Adam(q2_nn.parameters(), lr=3e-4)

# %%
logger = U.Logger(LOG_DIR)
# Out:
# Writing logs to: logs/doublependulum/repar-prioritized-schedule-v0-1

# %%
batcher.populate(n=1000, get_action_fn=policy.get_action)
# Out:
# Populating Replay Buffer...
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
for batch in batcher.get_batches(MAX_STEPS, policy.get_action):
    batch = batch.to_tensor().concat_batch()

    ##### Calculate losses ######
    q1_batch = q1_nn((batch.state_t, batch.action))
    q2_batch = q2_nn((batch.state_t, batch.action))
    v_batch = v_nn(batch.state_t)

    dist = policy.create_dist(batch.state_t)
    if REPAR:
        action, pre_tanh_action = dist.rsample_with_pre()
    else:
        action, pre_tanh_action = dist.sample_with_pre()
    log_prob = dist.log_prob_pre(pre_tanh_action).sum(-1, keepdim=True)
    log_prob /= float(REWARD_SCALE)

    # Q loss
    v_target_tp1 = v_nn_target(batch.state_tp1)
    q_t_next = U.estimators.td_target(rewards=batch.reward, dones=batch.done,
                                         v_tp1=v_target_tp1, gamma=GAMMA)
    q1_loss = F.mse_loss(q1_batch, q_t_next.detach())
    q2_loss = F.mse_loss(q2_batch, q_t_next.detach())

    # V loss    
    q1_new_t = q1_nn((batch.state_t, action))
    q2_new_t = q2_nn((batch.state_t, action))
    q_new_t = torch.min(q1_new_t, q2_new_t)
    next_value = q_new_t - log_prob
    v_loss = F.mse_loss(v_batch, next_value.detach())

    # Policy loss    
    if REPAR:        
        p_loss = (log_prob - q_new_t).mean()
    else:
        next_log_prob = q_new_t - v_batch
        p_loss = (log_prob * (log_prob - next_log_prob).detach()).mean()
    # Policy regularization losses
    mean_loss = 1e-3 * dist.loc.pow(2).mean()
    log_std_loss = 1e-3 * dist.scale.log().pow(2).mean()
    pre_tanh_loss = 0 * pre_tanh_action.pow(2).sum(1).mean()
    # Combine all losses
    p_loss += mean_loss + log_std_loss + pre_tanh_loss

    ###### Optimize ######
    q1_opt.zero_grad()
    q1_loss.backward()
#     torch.nn.utils.clip_grad_norm_(q1_nn.parameters(), CLIP_GRAD)
    q1_grad = U.mean_grad(q1_nn)
    q1_opt.step()

    q2_opt.zero_grad()
    q2_loss.backward()
#     torch.nn.utils.clip_grad_norm_(q2_nn.parameters(), CLIP_GRAD)
    q2_grad = U.mean_grad(q2_nn)
    q2_opt.step()

    v_opt.zero_grad()
    v_loss.backward()
#     torch.nn.utils.clip_grad_norm_(v_nn.parameters(), CLIP_GRAD)
    v_grad = U.mean_grad(v_nn)
    v_opt.step()

    p_opt.zero_grad()
    p_loss.backward()
#     torch.nn.utils.clip_grad_norm_(p_nn.parameters(), CLIP_GRAD)
    p_grad = U.mean_grad(p_nn)
    p_opt.step()

    ###### Update target value network ######
    U.copy_weights(from_nn=v_nn, to_nn=v_nn_target, weight=TARGET_UP_WEIGHT)
    
    ###### Update replay batcher priorities #######
    idx = U.to_np(batch.idx).astype('int')
    td_error = U.to_np((q_new_t - q_t_next).abs())
    batcher.update_pr(idx=idx, pr=td_error)

    ###### Write logs ######
    if batcher.num_steps % LOG_FREQ == 0 and batcher.runner.rewards:
        batcher.write_logs(logger)    

        logger.add_log('policy/loss', p_loss)
        logger.add_log('v/loss', v_loss)
        logger.add_log('q1/loss', q1_loss)
        logger.add_log('q2/loss', q2_loss)

        logger.add_log('policy/grad', p_grad)
        logger.add_log('v/grad', v_grad)
        logger.add_log('q1/grad', q1_grad)
        logger.add_log('q2/grad', q2_grad)

        logger.add_histogram('policy/log_prob', log_prob)
        logger.add_histogram('policy/mean', dist.loc)
        logger.add_histogram('policy/std', dist.scale.exp())
        logger.add_histogram('v/value', v_batch)
        logger.add_histogram('q1/value', q1_batch)
        logger.add_histogram('q2/value', q2_batch)

        logger.log(step=batcher.num_steps)
# Out:
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=80000), HTML(value='')), layout=Layout(displa…
#                          Step 2000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                              |  61.68
# Env/Length/Episode (New)                              |   6.77
# Env/Reward/Episode (Last 50)                          | 101.90
# Env/Length/Episode (Last 50)                          |  11.06
# policy/loss                                           | -49.51
# v/loss                                                |   3.02
# q1/loss                                               |  21.42
# q2/loss                                               |  19.52
# policy/grad                                           |  -0.01
# v/grad                                                |  -0.22
# q1/grad                                               |   0.01
# q2/grad                                               |  -0.07
# --------------------------------------------------------------
#
#                          Step 3000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                              | 147.69
# Env/Length/Episode (New)                              |  15.95
# Env/Reward/Episode (Last 50)                          | 152.41
# Env/Length/Episode (Last 50)                          |  16.46
# policy/loss                                           | -89.02
# v/loss                                                |  11.33
# q1/loss                                               |  17.66
# q2/loss                                               |  18.07
# policy/grad                                           |  -0.03
# v/grad                                                |   0.48
# q1/grad                                               |  -0.16
# q2/grad                                               |  -0.07
# --------------------------------------------------------------
#
#                          Step 4000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             |  241.23
# Env/Length/Episode (New)                             |   25.97
# Env/Reward/Episode (Last 50)                         |  228.00
# Env/Length/Episode (Last 50)                         |   24.56
# policy/loss                                          | -122.77
# v/loss                                               |   18.01
# q1/loss                                              |   28.85
# q2/loss                                              |   29.18
# policy/grad                                          |    0.82
# v/grad                                               |    1.61
# q1/grad                                              |   -0.43
# q2/grad                                              |   -0.61
# --------------------------------------------------------------
#
#                          Step 5000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             |  331.26
# Env/Length/Episode (New)                             |   35.63
# Env/Reward/Episode (Last 50)                         |  307.50
# Env/Length/Episode (Last 50)                         |   33.08
# policy/loss                                          | -175.27
# v/loss                                               |   18.77
# q1/loss                                              |   16.22
# q2/loss                                              |   15.06
# policy/grad                                          |    0.30
# v/grad                                               |   -1.05
# q1/grad                                              |   -0.73
# q2/grad                                              |   -0.40
# --------------------------------------------------------------
#
#                          Step 6000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             |  416.02
# Env/Length/Episode (New)                             |   44.70
# Env/Reward/Episode (Last 50)                         |  370.25
# Env/Length/Episode (Last 50)                         |   39.80
# policy/loss                                          | -189.13
# v/loss                                               |   17.62
# q1/loss                                              |   10.85
# q2/loss                                              |   10.72
# policy/grad                                          |   -0.05
# v/grad                                               |   -0.65
# q1/grad                                              |    0.18
# q2/grad                                              |    0.03
# --------------------------------------------------------------
#
#                          Step 7000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             |  503.55
# Env/Length/Episode (New)                             |   54.06
# Env/Reward/Episode (Last 50)                         |  434.76
# Env/Length/Episode (Last 50)                         |   46.70
# policy/loss                                          | -221.61
# v/loss                                               |   24.12
# q1/loss                                              |   13.93
# q2/loss                                              |   13.61
# policy/grad                                          |    0.67
# v/grad                                               |   -1.13
# q1/grad                                              |    0.07
# q2/grad                                              |    0.20
# --------------------------------------------------------------
#
#                          Step 8000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 1346.47
# Env/Length/Episode (New)                             |  144.17
# Env/Reward/Episode (Last 50)                         |  552.04
# Env/Length/Episode (Last 50)                         |   59.24
# policy/loss                                          | -212.85
# v/loss                                               |   46.21
# q1/loss                                              |   11.96
# q2/loss                                              |   14.45
# policy/grad                                          |    0.76
# v/grad                                               |   -0.30
# q1/grad                                              |   -0.26
# q2/grad                                              |   -0.29
# --------------------------------------------------------------
#
#                          Step 9000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 3366.83
# Env/Length/Episode (New)                             |  360.00
# Env/Reward/Episode (Last 50)                         |  614.75
# Env/Length/Episode (Last 50)                         |   65.94
# policy/loss                                          | -224.15
# v/loss                                               |   26.86
# q1/loss                                              |   13.16
# q2/loss                                              |   13.91
# policy/grad                                          |   -0.84
# v/grad                                               |   -0.35
# q1/grad                                              |   -0.14
# q2/grad                                              |   -0.07
# --------------------------------------------------------------
#
#                          Step 10000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9357.80
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         |  793.72
# Env/Length/Episode (Last 50)                         |   85.06
# policy/loss                                          | -245.43
# v/loss                                               |  104.01
# q1/loss                                              |  497.98
# q2/loss                                              |  502.20
# policy/grad                                          |   -0.26
# v/grad                                               |   -1.59
# q1/grad                                              |   -1.88
# q2/grad                                              |   -2.13
# --------------------------------------------------------------
#                          Step 11000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 6515.96
# Env/Length/Episode (New)                             |  696.50
# Env/Reward/Episode (Last 50)                         | 1041.54
# Env/Length/Episode (Last 50)                         |  111.54
# policy/loss                                          | -256.40
# v/loss                                               |   43.29
# q1/loss                                              |  565.89
# q2/loss                                              |  568.88
# policy/grad                                          |   -1.16
# v/grad                                               |   -0.62
# q1/grad                                              |   -0.44
# q2/grad                                              |   -1.06
# --------------------------------------------------------------
#
#                          Step 12000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9356.44
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 1221.41
# Env/Length/Episode (Last 50)                         |  130.76
# policy/loss                                          | -260.34
# v/loss                                               |   41.39
# q1/loss                                              |  510.13
# q2/loss                                              |  508.82
# policy/grad                                          |    0.85
# v/grad                                               |    0.67
# q1/grad                                              |   -0.39
# q2/grad                                              |   -0.29
# --------------------------------------------------------------
#
#                          Step 13000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9356.65
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 1400.91
# Env/Length/Episode (Last 50)                         |  149.94
# policy/loss                                          | -308.12
# v/loss                                               |   36.00
# q1/loss                                              |   21.18
# q2/loss                                              |   27.16
# policy/grad                                          |    0.28
# v/grad                                               |   -0.01
# q1/grad                                              |   -0.22
# q2/grad                                              |   -0.04
# --------------------------------------------------------------
#
#                          Step 14000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 4177.50
# Env/Length/Episode (New)                             |  447.00
# Env/Reward/Episode (Last 50)                         | 1478.51
# Env/Length/Episode (Last 50)                         |  158.24
# policy/loss                                          | -316.16
# v/loss                                               |   47.42
# q1/loss                                              |   43.41
# q2/loss                                              |   39.96
# policy/grad                                          |    0.43
# v/grad                                               |   -0.01
# q1/grad                                              |   -0.58
# q2/grad                                              |   -0.70
# --------------------------------------------------------------
#
#                          Step 15000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9358.76
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 1657.48
# Env/Length/Episode (Last 50)                         |  177.36
# policy/loss                                          | -305.85
# v/loss                                               |   43.90
# q1/loss                                              |  652.98
# q2/loss                                              |  662.78
# policy/grad                                          |   -0.42
# v/grad                                               |    2.08
# q1/grad                                              |   -0.66
# q2/grad                                              |   -1.28
# --------------------------------------------------------------
#
#                          Step 16000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9357.29
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 1838.49
# Env/Length/Episode (Last 50)                         |  196.70
# policy/loss                                          | -322.31
# v/loss                                               |   53.35
# q1/loss                                              |   41.70
# q2/loss                                              |   41.76
# policy/grad                                          |    0.21
# v/grad                                               |    2.07
# q1/grad                                              |    0.27
# q2/grad                                              |    0.45
# --------------------------------------------------------------
#
#                          Step 17000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 5191.53
# Env/Length/Episode (New)                             |  555.00
# Env/Reward/Episode (Last 50)                         | 2029.02
# Env/Length/Episode (Last 50)                         |  217.06
# policy/loss                                          | -329.93
# v/loss                                               |   33.29
# q1/loss                                              |  806.12
# q2/loss                                              |  798.45
# policy/grad                                          |   -0.02
# v/grad                                               |    0.82
# q1/grad                                              |    0.61
# q2/grad                                              |   -0.00
# --------------------------------------------------------------
#
#                          Step 18000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 4243.53
# Env/Length/Episode (New)                             |  453.75
# Env/Reward/Episode (Last 50)                         | 2336.33
# Env/Length/Episode (Last 50)                         |  249.90
# policy/loss                                          | -328.27
# v/loss                                               |  108.22
# q1/loss                                              |  646.43
# q2/loss                                              |  654.74
# policy/grad                                          |    0.54
# v/grad                                               |    6.89
# q1/grad                                              |    0.66
# q2/grad                                              |    2.64
# --------------------------------------------------------------
#
#                          Step 19000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 4262.39
# Env/Length/Episode (New)                             |  456.00
# Env/Reward/Episode (Last 50)                         | 2489.32
# Env/Length/Episode (Last 50)                         |  266.26
# policy/loss                                          | -333.35
# v/loss                                               |   57.86
# q1/loss                                              |  873.33
# q2/loss                                              |  850.48
# policy/grad                                          |    1.25
# v/grad                                               |    2.27
# q1/grad                                              |    0.67
# q2/grad                                              |    0.07
# --------------------------------------------------------------
#                          Step 20000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 1198.53
# Env/Length/Episode (New)                             |  128.33
# Env/Reward/Episode (Last 50)                         | 2577.65
# Env/Length/Episode (Last 50)                         |  275.70
# policy/loss                                          | -338.96
# v/loss                                               |   37.86
# q1/loss                                              |  687.43
# q2/loss                                              |  701.87
# policy/grad                                          |    2.26
# v/grad                                               |   -0.66
# q1/grad                                              |    0.19
# q2/grad                                              |   -1.18
# --------------------------------------------------------------
#
#                          Step 21000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 6267.45
# Env/Length/Episode (New)                             |  670.50
# Env/Reward/Episode (Last 50)                         | 2810.10
# Env/Length/Episode (Last 50)                         |  300.56
# policy/loss                                          | -363.28
# v/loss                                               |   68.51
# q1/loss                                              | 1492.16
# q2/loss                                              | 1469.76
# policy/grad                                          |   -0.26
# v/grad                                               |    1.72
# q1/grad                                              |    1.19
# q2/grad                                              |   -0.30
# --------------------------------------------------------------
#
#                          Step 22000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9352.15
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 2989.32
# Env/Length/Episode (Last 50)                         |  319.72
# policy/loss                                          | -359.85
# v/loss                                               |   96.22
# q1/loss                                              |  708.66
# q2/loss                                              |  717.36
# policy/grad                                          |   -1.12
# v/grad                                               |    5.36
# q1/grad                                              |   -1.03
# q2/grad                                              |    1.00
# --------------------------------------------------------------
#
#                          Step 23000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9353.36
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 3170.63
# Env/Length/Episode (Last 50)                         |  339.10
# policy/loss                                          | -393.95
# v/loss                                               |   64.10
# q1/loss                                              |  950.27
# q2/loss                                              |  941.56
# policy/grad                                          |    0.02
# v/grad                                               |   -5.47
# q1/grad                                              |    1.62
# q2/grad                                              |   -0.21
# --------------------------------------------------------------
#
#                          Step 24000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9353.12
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 3352.69
# Env/Length/Episode (Last 50)                         |  358.56
# policy/loss                                          | -387.89
# v/loss                                               |  164.15
# q1/loss                                              | 2136.68
# q2/loss                                              | 2123.71
# policy/grad                                          |    0.22
# v/grad                                               |   -9.02
# q1/grad                                              |    3.51
# q2/grad                                              |    1.49
# --------------------------------------------------------------
#
#                          Step 25000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9352.59
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 3532.85
# Env/Length/Episode (Last 50)                         |  377.82
# policy/loss                                          | -393.30
# v/loss                                               |   63.05
# q1/loss                                              | 3132.72
# q2/loss                                              | 3083.18
# policy/grad                                          |   -0.04
# v/grad                                               |   -5.74
# q1/grad                                              |    5.03
# q2/grad                                              |    0.66
# --------------------------------------------------------------
#
#                          Step 26000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9352.26
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 3712.07
# Env/Length/Episode (Last 50)                         |  396.98
# policy/loss                                          | -397.93
# v/loss                                               |   48.61
# q1/loss                                              |   55.25
# q2/loss                                              |   61.27
# policy/grad                                          |    0.29
# v/grad                                               |    2.74
# q1/grad                                              |   -0.44
# q2/grad                                              |   -0.40
# --------------------------------------------------------------
#
#                          Step 27000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9295.39
# Env/Length/Episode (New)                             |  994.00
# Env/Reward/Episode (Last 50)                         | 3890.53
# Env/Length/Episode (Last 50)                         |  416.06
# policy/loss                                          | -381.75
# v/loss                                               |   54.04
# q1/loss                                              | 1385.46
# q2/loss                                              | 1379.88
# policy/grad                                          |   -0.46
# v/grad                                               |    1.90
# q1/grad                                              |    0.45
# q2/grad                                              |    1.40
# --------------------------------------------------------------
#
#                          Step 28000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 6498.35
# Env/Length/Episode (New)                             |  695.00
# Env/Reward/Episode (Last 50)                         | 3995.64
# Env/Length/Episode (Last 50)                         |  427.30
# policy/loss                                          | -394.09
# v/loss                                               |   80.66
# q1/loss                                              |   54.64
# q2/loss                                              |   73.71
# policy/grad                                          |   -1.85
# v/grad                                               |   -7.59
# q1/grad                                              |    0.40
# q2/grad                                              |    0.83
# --------------------------------------------------------------
#                          Step 29000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 3440.26
# Env/Length/Episode (New)                             |  368.00
# Env/Reward/Episode (Last 50)                         | 4176.35
# Env/Length/Episode (Last 50)                         |  446.62
# policy/loss                                          | -384.88
# v/loss                                               |   36.61
# q1/loss                                              |  116.97
# q2/loss                                              |  147.22
# policy/grad                                          |   -0.60
# v/grad                                               |   -0.79
# q1/grad                                              |   -1.77
# q2/grad                                              |    0.22
# --------------------------------------------------------------
#
#                          Step 30000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9352.37
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 4357.64
# Env/Length/Episode (Last 50)                         |  466.00
# policy/loss                                          | -398.48
# v/loss                                               |   45.47
# q1/loss                                              |   50.56
# q2/loss                                              |   52.09
# policy/grad                                          |    0.72
# v/grad                                               |   -3.07
# q1/grad                                              |   -1.24
# q2/grad                                              |    0.02
# --------------------------------------------------------------
#
#                          Step 31000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9352.31
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 4526.02
# Env/Length/Episode (Last 50)                         |  484.00
# policy/loss                                          | -403.58
# v/loss                                               |   94.80
# q1/loss                                              | 2270.16
# q2/loss                                              | 2286.16
# policy/grad                                          |    0.48
# v/grad                                               |    7.25
# q1/grad                                              |    3.95
# q2/grad                                              |    2.77
# --------------------------------------------------------------
#
#                          Step 32000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9351.74
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 4707.12
# Env/Length/Episode (Last 50)                         |  503.36
# policy/loss                                          | -414.20
# v/loss                                               |   66.89
# q1/loss                                              | 1729.06
# q2/loss                                              | 1768.23
# policy/grad                                          |    0.18
# v/grad                                               |    3.45
# q1/grad                                              |    1.05
# q2/grad                                              |    0.14
# --------------------------------------------------------------
#
#                          Step 33000
# --------------------------------------------------------------
# Env/Reward/Episode (New)                             | 9352.31
# Env/Length/Episode (New)                             | 1000.00
# Env/Reward/Episode (Last 50)                         | 4886.72
# Env/Length/Episode (Last 50)                         |  522.56
# policy/loss                                          | -424.75
# v/loss                                               |   65.32
# q1/loss                                              |  133.43
# q2/loss                                              |  156.34
# policy/grad                                          |    0.21
# v/grad                                               |    5.25
# q1/grad                                              |   -2.87
# q2/grad                                              |   -0.97
# --------------------------------------------------------------
