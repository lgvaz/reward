# %%
import pdb
import gym
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import reward as rw
import reward.utils as U
# Out:
# /home/quazar/anaconda3/envs/torchrl_up/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
ENV = 'Humanoid-v2'
LOG_DIR = 'logs/humanoid/paper-v0-1'
REPAR = True
REWARD_SCALE = 20.
CLIP_GRAD = float('inf')
GAMMA = 0.99
TARGET_UP_WEIGHT = 0.005
BATCH_SIZE = 256
MAX_STEPS = 40e6

# %%
use_cuda = torch.cuda.is_available()
device   = torch.device("cuda" if use_cuda else "cpu")

# %%
env = rw.envs.GymEnv(ENV)
env = rw.envs.wrappers.ActionBound(env)
runner = rw.runners.SingleRunner(env)
batcher = rw.batchers.ReplayBatcher(
    runner=runner,
    batch_size=256,
    replay_buffer_maxlen=1e6,
    learning_freq=1,
    grad_steps_per_batch=1,
    transforms=[
#         rw.batchers.transforms.StateRunNorm(),
        rw.batchers.transforms.RewardConstScaler(REWARD_SCALE),
    ],
)

state_features = batcher.get_state_info().shape[0]
num_actions = batcher.get_action_info().shape[0]
# Out:
# Choosing the latest nvidia driver: /usr/lib/nvidia-390, among ['/usr/lib/nvidia-375', '/usr/lib/nvidia-390']
# Choosing the latest nvidia driver: /usr/lib/nvidia-390, among ['/usr/lib/nvidia-375', '/usr/lib/nvidia-390']
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
class PolicyNN(nn.Module):
    def __init__(self, num_inputs, num_outputs, hidden_units=256,
                 activation=nn.ReLU, log_std_range=(-20, 2)):
        super().__init__()
        self.log_std_range = log_std_range
        
        layers = []
        layers += [nn.Linear(num_inputs, hidden_units), activation()]
        layers += [nn.Linear(hidden_units, hidden_units), activation()]
        self.layers = nn.Sequential(*layers)
        
        self.mean = nn.Linear(hidden_units, num_outputs)
        self.mean.weight.data.uniform_(-3e-3, 3e-3)
        self.mean.bias.data.uniform_(-3e-3, 3e-3)
        
        self.log_std = nn.Linear(hidden_units, num_outputs)
        self.log_std.weight.data.uniform_(-3e-3, 3e-3)
        self.log_std.bias.data.uniform_(-3e-3, 3e-3)
        
    def forward(self, x):
        x = self.layers(x)
        mean = self.mean(x)
        log_std = self.log_std(x).clamp(*self.log_std_range)
        return mean, log_std

# %%
class ValueNN(nn.Module):
    def __init__(self, num_inputs, hidden_units=256, activation=nn.ReLU):
        super().__init__()
        
        layers = []
        layers += [nn.Linear(num_inputs, hidden_units), activation()]
        layers += [nn.Linear(hidden_units, hidden_units), activation()]
        final_layer = nn.Linear(hidden_units, 1)
        final_layer.weight.data.uniform_(-3e-3, 3e-3)
        final_layer.bias.data.uniform_(-3e-3, 3e-3)
        layers += [final_layer]
        
        self.layers = nn.Sequential(*layers)
        
    def forward(self, x):
        return self.layers(x)

# %%
class QValueNN(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_units=256, activation=nn.ReLU):
        super().__init__()
        
        layers = []
        layers += [nn.Linear(num_inputs + num_actions, hidden_units), activation()]
        layers += [nn.Linear(hidden_units, hidden_units), activation()]
        final_layer = nn.Linear(hidden_units, 1)
        final_layer.weight.data.uniform_(-3e-3, 3e-3)
        final_layer.bias.data.uniform_(-3e-3, 3e-3)
        layers += [final_layer]
        
        self.layers = nn.Sequential(*layers)
        
    def forward(self, x):
        state, action = x
        x = torch.cat([state, action], dim=1)
        return self.layers(x)

# %%
class TanhNormalPolicy(rw.policy.BasePolicy):
    def create_dist(self, state):
        parameters = self.nn(state)
        mean, log_std = parameters
        return rw.distributions.TanhNormal(loc=mean, scale=log_std.exp())

    def get_action(self, state, step):
        dist = self.create_dist(state=state)
        action = U.to_np(dist.sample())
        assert not np.isnan(action).any()
        return action

# %%
p_nn = PolicyNN(num_inputs=state_features, num_outputs=num_actions).to(device)
v_nn = ValueNN(num_inputs=state_features).to(device)
v_nn_target = ValueNN(num_inputs=state_features).to(device).eval()
q1_nn = QValueNN(num_inputs=state_features, num_actions=num_actions).to(device)
q2_nn = QValueNN(num_inputs=state_features, num_actions=num_actions).to(device)

# %%
U.copy_weights(from_nn=v_nn, to_nn=v_nn_target, weight=1.)

# %%
policy = TanhNormalPolicy(nn=p_nn)

# %%
p_opt = torch.optim.Adam(p_nn.parameters(), lr=3e-4)
v_opt = torch.optim.Adam(v_nn.parameters(), lr=3e-4)
q1_opt = torch.optim.Adam(q1_nn.parameters(), lr=3e-4)
q2_opt = torch.optim.Adam(q2_nn.parameters(), lr=3e-4)

# %%
logger = U.Logger(LOG_DIR)
# Out:
# Writing logs to: logs/humanoid/paper-v0-1

# %%
batcher.populate(n=1000, get_action_fn=policy.get_action)
# Out:
# Populating Replay Buffer...
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
for batch in batcher.get_batches(MAX_STEPS, policy.get_action):
    batch = batch.to_tensor().concat_batch()

    ##### Calculate losses ######
    q1_batch = q1_nn((batch.state_t, batch.action))
    q2_batch = q2_nn((batch.state_t, batch.action))
    v_batch = v_nn(batch.state_t)

    dist = policy.create_dist(batch.state_t)
    if REPAR:
        action, pre_tanh_action = dist.rsample_with_pre()
    else:
        action, pre_tanh_action = dist.sample_with_pre()
    log_prob = dist.log_prob_pre(pre_tanh_action).sum(-1, keepdim=True)

    # Q loss
    v_target_tp1 = v_nn_target(batch.state_tp1)
    q_value_tp1 = U.estimators.td_target(rewards=batch.reward, dones=batch.done,
                                         v_tp1=v_target_tp1, gamma=GAMMA)
    q1_loss = F.mse_loss(q1_batch, q_value_tp1.detach())
    q2_loss = F.mse_loss(q2_batch, q_value_tp1.detach())

    # V loss    
    q1_new_t = q1_nn((batch.state_t, action))
    q2_new_t = q2_nn((batch.state_t, action))
    q_new_t = torch.min(q1_new_t, q2_new_t)
    next_value = q_new_t - log_prob
    v_loss = F.mse_loss(v_batch, next_value.detach())

    # Policy loss    
    if REPAR:        
        p_loss = (log_prob - q_new_t).mean()
    else:
        next_log_prob = q_new_t - v_batch
        p_loss = (log_prob * (log_prob - next_log_prob).detach()).mean()
    # Policy regularization losses
    mean_loss = 1e-3 * dist.loc.pow(2).mean()
    log_std_loss = 1e-3 * dist.scale.log().pow(2).mean()
    pre_tanh_loss = 0 * pre_tanh_action.pow(2).sum(1).mean()
    # Combine all losses
    p_loss += mean_loss + log_std_loss + pre_tanh_loss

    ###### Optimize ######
    q1_opt.zero_grad()
    q1_loss.backward()
#     torch.nn.utils.clip_grad_norm_(q1_nn.parameters(), CLIP_GRAD)
    q1_grad = U.mean_grad(q1_nn)
    q1_opt.step()

    q2_opt.zero_grad()
    q2_loss.backward()
#     torch.nn.utils.clip_grad_norm_(q2_nn.parameters(), CLIP_GRAD)
    q2_grad = U.mean_grad(q2_nn)
    q2_opt.step()

    v_opt.zero_grad()
    v_loss.backward()
#     torch.nn.utils.clip_grad_norm_(v_nn.parameters(), CLIP_GRAD)
    v_grad = U.mean_grad(v_nn)
    v_opt.step()

    p_opt.zero_grad()
    p_loss.backward()
#     torch.nn.utils.clip_grad_norm_(p_nn.parameters(), CLIP_GRAD)
    p_grad = U.mean_grad(p_nn)
    p_opt.step()

    ###### Update target value network ######
    U.copy_weights(from_nn=v_nn, to_nn=v_nn_target, weight=TARGET_UP_WEIGHT)

    ###### Write logs ######
    if batcher.num_steps % 4000 == 0 and batcher.runner.rewards:
        batcher.write_logs(logger)    

        logger.add_log('policy/loss', p_loss)
        logger.add_log('v/loss', v_loss)
        logger.add_log('q1/loss', q1_loss)
        logger.add_log('q2/loss', q2_loss)

        logger.add_log('policy/grad', p_grad)
        logger.add_log('v/grad', v_grad)
        logger.add_log('q1/grad', q1_grad)
        logger.add_log('q2/grad', q2_grad)

        logger.add_histogram('policy/log_prob', log_prob)
        logger.add_histogram('policy/mean', dist.loc)
        logger.add_histogram('policy/std', dist.scale.exp())
        logger.add_histogram('v/value', v_batch)
        logger.add_histogram('q1/value', q1_batch)
        logger.add_histogram('q2/value', q2_batch)

        logger.log(step=batcher.num_steps)
# Out:
# HBox(children=(IntProgress(value=0, layout=Layout(flex='2'), max=40000000), HTML(value='')), layout=Layout(dis…
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   121.18
# Env/Length/Episode (New)                            |    24.49
# Env/Reward/Episode (Last 50)                        |   178.31
# Env/Length/Episode (Last 50)                        |    34.74
# policy/loss                                         | -1071.56
# v/loss                                              |  3609.77
# q1/loss                                             |  8477.33
# q2/loss                                             |  8528.21
# policy/grad                                         |     0.01
# v/grad                                              |  -375.73
# q1/grad                                             |   160.64
# q2/grad                                             |    48.89
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   279.36
# Env/Length/Episode (New)                            |    55.79
# Env/Reward/Episode (Last 50)                        |   303.58
# Env/Length/Episode (Last 50)                        |    61.20
# policy/loss                                         | -2002.04
# v/loss                                              |  5787.38
# q1/loss                                             |  8966.82
# q2/loss                                             |  8835.03
# policy/grad                                         |    -0.00
# v/grad                                              |  -314.71
# q1/grad                                             |    71.38
# q2/grad                                             |    93.02
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   355.26
# Env/Length/Episode (New)                            |    71.46
# Env/Reward/Episode (Last 50)                        |   350.60
# Env/Length/Episode (Last 50)                        |    70.48
# policy/loss                                         | -2265.18
# v/loss                                              |  5618.13
# q1/loss                                             |  8083.38
# q2/loss                                             |  7974.85
# policy/grad                                         |    -0.01
# v/grad                                              |  -351.52
# q1/grad                                             |   300.77
# q2/grad                                             |   547.75
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   315.33
# Env/Length/Episode (New)                            |    62.33
# Env/Reward/Episode (Last 50)                        |   310.32
# Env/Length/Episode (Last 50)                        |    61.04
# policy/loss                                         | -2190.36
# v/loss                                              |  8362.88
# q1/loss                                             |  8891.82
# q2/loss                                             |  8897.64
# policy/grad                                         |     0.01
# v/grad                                              | -1070.66
# q1/grad                                             |   628.12
# q2/grad                                             |   574.53
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   347.90
# Env/Length/Episode (New)                            |    67.07
# Env/Reward/Episode (Last 50)                        |   357.39
# Env/Length/Episode (Last 50)                        |    69.06
# policy/loss                                         | -2314.46
# v/loss                                              |  5572.42
# q1/loss                                             |  8755.36
# q2/loss                                             |  9412.68
# policy/grad                                         |     0.01
# v/grad                                              |  -275.77
# q1/grad                                             |   239.94
# q2/grad                                             |  -152.31
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   363.02
# Env/Length/Episode (New)                            |    72.00
# Env/Reward/Episode (Last 50)                        |   363.60
# Env/Length/Episode (Last 50)                        |    71.76
# policy/loss                                         | -2356.32
# v/loss                                              |  5244.74
# q1/loss                                             | 12991.63
# q2/loss                                             | 10544.31
# policy/grad                                         |     0.01
# v/grad                                              |   833.48
# q1/grad                                             | -1108.22
# q2/grad                                             |  -403.08
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   407.03
# Env/Length/Episode (New)                            |    85.26
# Env/Reward/Episode (Last 50)                        |   399.12
# Env/Length/Episode (Last 50)                        |    83.82
# policy/loss                                         | -2310.33
# v/loss                                              |  4469.61
# q1/loss                                             |  8102.62
# q2/loss                                             |  9272.14
# policy/grad                                         |     0.01
# v/grad                                              |   375.38
# q1/grad                                             |   115.88
# q2/grad                                             |  -236.69
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   408.09
# Env/Length/Episode (New)                            |    86.70
# Env/Reward/Episode (Last 50)                        |   420.27
# Env/Length/Episode (Last 50)                        |    88.82
# policy/loss                                         | -2225.62
# v/loss                                              |  6335.99
# q1/loss                                             | 11924.82
# q2/loss                                             | 13533.36
# policy/grad                                         |    -0.01
# v/grad                                              |   182.29
# q1/grad                                             |   214.85
# q2/grad                                             |   113.68
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   390.88
# Env/Length/Episode (New)                            |    83.88
# Env/Reward/Episode (Last 50)                        |   392.73
# Env/Length/Episode (Last 50)                        |    84.22
# policy/loss                                         | -2256.11
# v/loss                                              |  4678.13
# q1/loss                                             | 11966.65
# q2/loss                                             |  9266.34
# policy/grad                                         |     0.02
# v/grad                                              |  -159.95
# q1/grad                                             |  -287.22
# q2/grad                                             |   -65.19
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   400.04
# Env/Length/Episode (New)                            |    85.20
# Env/Reward/Episode (Last 50)                        |   402.99
# Env/Length/Episode (Last 50)                        |    85.86
# policy/loss                                         | -2430.41
# v/loss                                              |  4289.85
# q1/loss                                             |  6594.27
# q2/loss                                             |  5743.15
# policy/grad                                         |    -0.02
# v/grad                                              |  -972.29
# q1/grad                                             |   159.44
# q2/grad                                             |   112.75
# --------------------------------------------------------------
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   379.81
# Env/Length/Episode (New)                            |    78.71
# Env/Reward/Episode (Last 50)                        |   376.54
# Env/Length/Episode (Last 50)                        |    78.08
# policy/loss                                         | -2135.46
# v/loss                                              |  7274.07
# q1/loss                                             |  7576.76
# q2/loss                                             |  9372.70
# policy/grad                                         |    -0.01
# v/grad                                              |  1775.26
# q1/grad                                             |    97.51
# q2/grad                                             |  -486.52
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   380.35
# Env/Length/Episode (New)                            |    78.27
# Env/Reward/Episode (Last 50)                        |   377.51
# Env/Length/Episode (Last 50)                        |    77.72
# policy/loss                                         | -2658.83
# v/loss                                              |  5334.96
# q1/loss                                             |  6409.03
# q2/loss                                             |  6877.86
# policy/grad                                         |     0.02
# v/grad                                              |  -960.61
# q1/grad                                             |   624.23
# q2/grad                                             |   273.47
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   383.89
# Env/Length/Episode (New)                            |    78.41
# Env/Reward/Episode (Last 50)                        |   382.94
# Env/Length/Episode (Last 50)                        |    78.32
# policy/loss                                         | -2553.69
# v/loss                                              |  4441.36
# q1/loss                                             |  7944.03
# q2/loss                                             |  7276.22
# policy/grad                                         |    -0.00
# v/grad                                              | -1048.97
# q1/grad                                             |   588.17
# q2/grad                                             |    62.96
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   438.01
# Env/Length/Episode (New)                            |    86.46
# Env/Reward/Episode (Last 50)                        |   428.52
# Env/Length/Episode (Last 50)                        |    84.42
# policy/loss                                         | -2529.63
# v/loss                                              |  5622.25
# q1/loss                                             |  7690.96
# q2/loss                                             |  8602.20
# policy/grad                                         |     0.01
# v/grad                                              |   139.76
# q1/grad                                             |    78.46
# q2/grad                                             |   -61.06
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   382.95
# Env/Length/Episode (New)                            |    76.00
# Env/Reward/Episode (Last 50)                        |   381.26
# Env/Length/Episode (Last 50)                        |    75.76
# policy/loss                                         | -2695.30
# v/loss                                              |  5233.73
# q1/loss                                             |  8976.43
# q2/loss                                             |  7883.49
# policy/grad                                         |     0.01
# v/grad                                              |  1727.32
# q1/grad                                             |  -695.72
# q2/grad                                             |  -446.35
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   430.07
# Env/Length/Episode (New)                            |    85.19
# Env/Reward/Episode (Last 50)                        |   429.63
# Env/Length/Episode (Last 50)                        |    84.98
# policy/loss                                         | -2659.62
# v/loss                                              |  6720.72
# q1/loss                                             | 12776.53
# q2/loss                                             | 15163.16
# policy/grad                                         |     0.03
# v/grad                                              |  1222.94
# q1/grad                                             |   180.23
# q2/grad                                             |  -166.60
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   403.23
# Env/Length/Episode (New)                            |    81.22
# Env/Reward/Episode (Last 50)                        |   404.16
# Env/Length/Episode (Last 50)                        |    81.36
# policy/loss                                         | -2694.06
# v/loss                                              |  5784.72
# q1/loss                                             |  6635.88
# q2/loss                                             |  5045.70
# policy/grad                                         |    -0.01
# v/grad                                              |   657.13
# q1/grad                                             |   129.48
# q2/grad                                             |    60.06
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   431.06
# Env/Length/Episode (New)                            |    86.83
# Env/Reward/Episode (Last 50)                        |   431.98
# Env/Length/Episode (Last 50)                        |    86.92
# policy/loss                                         | -2785.61
# v/loss                                              |  3688.23
# q1/loss                                             |  8674.91
# q2/loss                                             |  7058.03
# policy/grad                                         |    -0.02
# v/grad                                              |  -269.65
# q1/grad                                             |   188.37
# q2/grad                                             |   352.10
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   447.04
# Env/Length/Episode (New)                            |    92.42
# Env/Reward/Episode (Last 50)                        |   444.85
# Env/Length/Episode (Last 50)                        |    92.02
# policy/loss                                         | -2752.29
# v/loss                                              |  6169.22
# q1/loss                                             |  6872.67
# q2/loss                                             |  7028.52
# policy/grad                                         |     0.01
# v/grad                                              |  1172.95
# q1/grad                                             |   -48.78
# q2/grad                                             |  -180.06
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   460.51
# Env/Length/Episode (New)                            |    93.88
# Env/Reward/Episode (Last 50)                        |   461.62
# Env/Length/Episode (Last 50)                        |    95.00
# policy/loss                                         | -2875.79
# v/loss                                              |  3292.89
# q1/loss                                             |  7100.06
# q2/loss                                             |  6984.31
# policy/grad                                         |     0.01
# v/grad                                              |   166.30
# q1/grad                                             |    52.92
# q2/grad                                             |  -572.99
# --------------------------------------------------------------
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   437.22
# Env/Length/Episode (New)                            |    88.09
# Env/Reward/Episode (Last 50)                        |   440.59
# Env/Length/Episode (Last 50)                        |    88.56
# policy/loss                                         | -2538.03
# v/loss                                              |  3858.49
# q1/loss                                             | 12747.73
# q2/loss                                             | 13180.04
# policy/grad                                         |     0.01
# v/grad                                              |  -270.66
# q1/grad                                             |  -389.09
# q2/grad                                             |  -182.70
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   446.70
# Env/Length/Episode (New)                            |    93.28
# Env/Reward/Episode (Last 50)                        |   451.73
# Env/Length/Episode (Last 50)                        |    93.54
# policy/loss                                         | -2661.43
# v/loss                                              |  6050.23
# q1/loss                                             |  8694.98
# q2/loss                                             |  8010.48
# policy/grad                                         |    -0.02
# v/grad                                              |   936.84
# q1/grad                                             |  -720.96
# q2/grad                                             |  -176.23
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   425.28
# Env/Length/Episode (New)                            |    87.98
# Env/Reward/Episode (Last 50)                        |   430.25
# Env/Length/Episode (Last 50)                        |    88.62
# policy/loss                                         | -2811.61
# v/loss                                              |  3753.57
# q1/loss                                             |  9369.03
# q2/loss                                             |  8243.08
# policy/grad                                         |     0.00
# v/grad                                              |  -654.88
# q1/grad                                             |   315.23
# q2/grad                                             |   480.65
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   457.50
# Env/Length/Episode (New)                            |    93.47
# Env/Reward/Episode (Last 50)                        |   453.87
# Env/Length/Episode (Last 50)                        |    93.08
# policy/loss                                         | -2655.19
# v/loss                                              |  5933.51
# q1/loss                                             | 12514.70
# q2/loss                                             | 10774.15
# policy/grad                                         |    -0.00
# v/grad                                              |    30.51
# q1/grad                                             |   436.96
# q2/grad                                             |   209.81
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   429.61
# Env/Length/Episode (New)                            |    85.23
# Env/Reward/Episode (Last 50)                        |   428.08
# Env/Length/Episode (Last 50)                        |    84.82
# policy/loss                                         | -2645.50
# v/loss                                              |  3272.94
# q1/loss                                             |  6875.98
# q2/loss                                             | 10068.11
# policy/grad                                         |    -0.01
# v/grad                                              |  -277.16
# q1/grad                                             |   347.14
# q2/grad                                             |   493.54
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   462.54
# Env/Length/Episode (New)                            |    92.74
# Env/Reward/Episode (Last 50)                        |   443.11
# Env/Length/Episode (Last 50)                        |    88.50
# policy/loss                                         | -2849.10
# v/loss                                              |  3914.16
# q1/loss                                             |  9155.77
# q2/loss                                             | 10271.79
# policy/grad                                         |     0.00
# v/grad                                              |   -42.60
# q1/grad                                             |  -608.44
# q2/grad                                             |  -455.87
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   523.96
# Env/Length/Episode (New)                            |   103.33
# Env/Reward/Episode (Last 50)                        |   511.92
# Env/Length/Episode (Last 50)                        |   101.40
# policy/loss                                         | -2863.84
# v/loss                                              |  6999.88
# q1/loss                                             | 13373.49
# q2/loss                                             | 12281.49
# policy/grad                                         |    -0.02
# v/grad                                              |  -733.76
# q1/grad                                             |  -155.39
# q2/grad                                             |    99.55
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   519.15
# Env/Length/Episode (New)                            |   103.49
# Env/Reward/Episode (Last 50)                        |   523.45
# Env/Length/Episode (Last 50)                        |   104.36
# policy/loss                                         | -2935.81
# v/loss                                              |  2257.67
# q1/loss                                             |  6193.84
# q2/loss                                             |  5637.24
# policy/grad                                         |    -0.01
# v/grad                                              |  -367.41
# q1/grad                                             |   261.17
# q2/grad                                             |   201.56
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   513.02
# Env/Length/Episode (New)                            |   101.46
# Env/Reward/Episode (Last 50)                        |   522.66
# Env/Length/Episode (Last 50)                        |   104.38
# policy/loss                                         | -2811.44
# v/loss                                              |  5326.73
# q1/loss                                             | 12700.01
# q2/loss                                             | 19068.41
# policy/grad                                         |    -0.01
# v/grad                                              |  1618.51
# q1/grad                                             |   -21.68
# q2/grad                                             |    69.25
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   523.25
# Env/Length/Episode (New)                            |   103.31
# Env/Reward/Episode (Last 50)                        |   523.71
# Env/Length/Episode (Last 50)                        |   103.12
# policy/loss                                         | -2865.59
# v/loss                                              |  4893.25
# q1/loss                                             |  9932.00
# q2/loss                                             | 11478.93
# policy/grad                                         |    -0.03
# v/grad                                              |  -832.84
# q1/grad                                             |   464.26
# q2/grad                                             |   193.57
# --------------------------------------------------------------
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   547.01
# Env/Length/Episode (New)                            |   110.11
# Env/Reward/Episode (Last 50)                        |   530.44
# Env/Length/Episode (Last 50)                        |   106.32
# policy/loss                                         | -3025.18
# v/loss                                              |  3673.85
# q1/loss                                             |  7223.64
# q2/loss                                             |  7452.43
# policy/grad                                         |    -0.02
# v/grad                                              |   261.32
# q1/grad                                             |   748.79
# q2/grad                                             |   395.08
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   535.54
# Env/Length/Episode (New)                            |   108.41
# Env/Reward/Episode (Last 50)                        |   538.25
# Env/Length/Episode (Last 50)                        |   109.16
# policy/loss                                         | -3139.16
# v/loss                                              |  5912.35
# q1/loss                                             |  7825.25
# q2/loss                                             | 10460.85
# policy/grad                                         |    -0.00
# v/grad                                              |  1359.69
# q1/grad                                             |  -191.92
# q2/grad                                             |  -763.44
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   521.49
# Env/Length/Episode (New)                            |   105.14
# Env/Reward/Episode (Last 50)                        |   518.40
# Env/Length/Episode (Last 50)                        |   104.84
# policy/loss                                         | -3007.42
# v/loss                                              |  4807.08
# q1/loss                                             |  9492.69
# q2/loss                                             |  8714.14
# policy/grad                                         |    -0.00
# v/grad                                              |   798.38
# q1/grad                                             |  -707.60
# q2/grad                                             |  -372.73
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   490.79
# Env/Length/Episode (New)                            |    97.90
# Env/Reward/Episode (Last 50)                        |   500.84
# Env/Length/Episode (Last 50)                        |    99.96
# policy/loss                                         | -3005.13
# v/loss                                              |  7712.83
# q1/loss                                             | 11275.71
# q2/loss                                             | 11233.28
# policy/grad                                         |    -0.01
# v/grad                                              | -1970.77
# q1/grad                                             |  1035.86
# q2/grad                                             |  1017.67
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   517.03
# Env/Length/Episode (New)                            |   103.74
# Env/Reward/Episode (Last 50)                        |   505.47
# Env/Length/Episode (Last 50)                        |   100.70
# policy/loss                                         | -2709.98
# v/loss                                              |  4829.17
# q1/loss                                             |  7194.22
# q2/loss                                             |  7645.79
# policy/grad                                         |    -0.00
# v/grad                                              | -1549.18
# q1/grad                                             |   684.48
# q2/grad                                             |   433.55
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   516.21
# Env/Length/Episode (New)                            |   102.62
# Env/Reward/Episode (Last 50)                        |   519.14
# Env/Length/Episode (Last 50)                        |   103.48
# policy/loss                                         | -2976.62
# v/loss                                              |  7265.15
# q1/loss                                             |  7059.42
# q2/loss                                             |  8635.59
# policy/grad                                         |    -0.01
# v/grad                                              |  2397.97
# q1/grad                                             |  -223.38
# q2/grad                                             |   -66.34
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   523.12
# Env/Length/Episode (New)                            |   104.41
# Env/Reward/Episode (Last 50)                        |   529.63
# Env/Length/Episode (Last 50)                        |   105.28
# policy/loss                                         | -3095.78
# v/loss                                              |  5872.60
# q1/loss                                             |  8300.88
# q2/loss                                             |  6724.64
# policy/grad                                         |     0.00
# v/grad                                              |   183.53
# q1/grad                                             |   204.26
# q2/grad                                             |    99.84
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   534.15
# Env/Length/Episode (New)                            |   104.42
# Env/Reward/Episode (Last 50)                        |   533.24
# Env/Length/Episode (Last 50)                        |   104.32
# policy/loss                                         | -3158.94
# v/loss                                              | 16238.53
# q1/loss                                             | 10818.05
# q2/loss                                             | 11712.13
# policy/grad                                         |    -0.01
# v/grad                                              | -4563.06
# q1/grad                                             |   816.19
# q2/grad                                             |   639.69
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   537.36
# Env/Length/Episode (New)                            |   109.57
# Env/Reward/Episode (Last 50)                        |   534.02
# Env/Length/Episode (Last 50)                        |   108.24
# policy/loss                                         | -3076.79
# v/loss                                              |  4396.99
# q1/loss                                             | 12035.62
# q2/loss                                             |  8773.22
# policy/grad                                         |    -0.02
# v/grad                                              |  -851.23
# q1/grad                                             |  1005.97
# q2/grad                                             |   621.14
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   523.00
# Env/Length/Episode (New)                            |   105.57
# Env/Reward/Episode (Last 50)                        |   534.40
# Env/Length/Episode (Last 50)                        |   108.62
# policy/loss                                         | -2992.44
# v/loss                                              |  3712.86
# q1/loss                                             | 11456.52
# q2/loss                                             | 11003.37
# policy/grad                                         |    -0.01
# v/grad                                              |   985.25
# q1/grad                                             |  -417.13
# q2/grad                                             |   -60.34
# --------------------------------------------------------------
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   472.94
# Env/Length/Episode (New)                            |    98.44
# Env/Reward/Episode (Last 50)                        |   477.25
# Env/Length/Episode (Last 50)                        |    98.32
# policy/loss                                         | -3178.41
# v/loss                                              |  4266.91
# q1/loss                                             |  6185.70
# q2/loss                                             |  6122.18
# policy/grad                                         |    -0.00
# v/grad                                              |   921.86
# q1/grad                                             |   -67.88
# q2/grad                                             |   -75.42
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   506.96
# Env/Length/Episode (New)                            |   101.33
# Env/Reward/Episode (Last 50)                        |   494.06
# Env/Length/Episode (Last 50)                        |    99.24
# policy/loss                                         | -2885.63
# v/loss                                              |  6081.33
# q1/loss                                             |  9381.99
# q2/loss                                             |  8723.54
# policy/grad                                         |    -0.00
# v/grad                                              |  -558.30
# q1/grad                                             |  -121.90
# q2/grad                                             |   -15.17
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   523.38
# Env/Length/Episode (New)                            |   105.73
# Env/Reward/Episode (Last 50)                        |   518.56
# Env/Length/Episode (Last 50)                        |   104.10
# policy/loss                                         | -3248.75
# v/loss                                              |  5134.11
# q1/loss                                             |  9995.45
# q2/loss                                             |  8572.87
# policy/grad                                         |     0.00
# v/grad                                              |  -653.53
# q1/grad                                             |   -83.90
# q2/grad                                             |   179.30
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   524.16
# Env/Length/Episode (New)                            |   103.28
# Env/Reward/Episode (Last 50)                        |   518.91
# Env/Length/Episode (Last 50)                        |   103.52
# policy/loss                                         | -3222.58
# v/loss                                              |  3422.84
# q1/loss                                             |  4812.21
# q2/loss                                             |  5750.64
# policy/grad                                         |     0.02
# v/grad                                              |   274.53
# q1/grad                                             |  -111.41
# q2/grad                                             |   -18.38
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   581.34
# Env/Length/Episode (New)                            |   115.00
# Env/Reward/Episode (Last 50)                        |   564.20
# Env/Length/Episode (Last 50)                        |   111.52
# policy/loss                                         | -3006.03
# v/loss                                              |  4772.60
# q1/loss                                             |  7119.44
# q2/loss                                             |  7940.81
# policy/grad                                         |    -0.00
# v/grad                                              |  -425.22
# q1/grad                                             |   350.48
# q2/grad                                             |   588.29
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   513.96
# Env/Length/Episode (New)                            |    99.28
# Env/Reward/Episode (Last 50)                        |   529.17
# Env/Length/Episode (Last 50)                        |   102.42
# policy/loss                                         | -2904.88
# v/loss                                              |  3381.76
# q1/loss                                             |  6170.63
# q2/loss                                             |  7583.63
# policy/grad                                         |    -0.00
# v/grad                                              |  -691.49
# q1/grad                                             |    83.58
# q2/grad                                             |   195.63
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   632.43
# Env/Length/Episode (New)                            |   126.06
# Env/Reward/Episode (Last 50)                        |   588.36
# Env/Length/Episode (Last 50)                        |   115.96
# policy/loss                                         | -2930.80
# v/loss                                              |  5595.83
# q1/loss                                             | 14548.97
# q2/loss                                             | 11755.62
# policy/grad                                         |    -0.00
# v/grad                                              |  1726.76
# q1/grad                                             |  -497.51
# q2/grad                                             |  -392.53
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   600.17
# Env/Length/Episode (New)                            |   120.91
# Env/Reward/Episode (Last 50)                        |   594.29
# Env/Length/Episode (Last 50)                        |   119.46
# policy/loss                                         | -3218.85
# v/loss                                              |  3347.43
# q1/loss                                             | 10436.86
# q2/loss                                             | 10422.02
# policy/grad                                         |     0.02
# v/grad                                              |  1020.53
# q1/grad                                             |   309.96
# q2/grad                                             |  -314.85
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   629.09
# Env/Length/Episode (New)                            |   126.09
# Env/Reward/Episode (Last 50)                        |   636.81
# Env/Length/Episode (Last 50)                        |   128.70
# policy/loss                                         | -3403.02
# v/loss                                              |  7088.55
# q1/loss                                             | 10753.27
# q2/loss                                             |  9075.12
# policy/grad                                         |    -0.02
# v/grad                                              |  1472.18
# q1/grad                                             |  -285.87
# q2/grad                                             |   -91.68
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   619.76
# Env/Length/Episode (New)                            |   124.72
# Env/Reward/Episode (Last 50)                        |   613.57
# Env/Length/Episode (Last 50)                        |   123.46
# policy/loss                                         | -3179.41
# v/loss                                              |  4007.29
# q1/loss                                             | 11596.78
# q2/loss                                             |  9442.36
# policy/grad                                         |     0.01
# v/grad                                              |  -608.82
# q1/grad                                             |  -185.64
# q2/grad                                             |    53.06
# --------------------------------------------------------------
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   644.77
# Env/Length/Episode (New)                            |   131.70
# Env/Reward/Episode (Last 50)                        |   654.50
# Env/Length/Episode (Last 50)                        |   132.88
# policy/loss                                         | -3017.27
# v/loss                                              |  5098.58
# q1/loss                                             | 31413.42
# q2/loss                                             | 32794.40
# policy/grad                                         |    -0.02
# v/grad                                              |   642.67
# q1/grad                                             |   703.30
# q2/grad                                             |   441.52
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   674.60
# Env/Length/Episode (New)                            |   135.30
# Env/Reward/Episode (Last 50)                        |   650.70
# Env/Length/Episode (Last 50)                        |   131.44
# policy/loss                                         | -3411.21
# v/loss                                              |  4148.53
# q1/loss                                             | 11320.64
# q2/loss                                             | 12152.93
# policy/grad                                         |    -0.03
# v/grad                                              | -1159.89
# q1/grad                                             |    71.54
# q2/grad                                             |   490.60
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   597.58
# Env/Length/Episode (New)                            |   120.06
# Env/Reward/Episode (Last 50)                        |   609.44
# Env/Length/Episode (Last 50)                        |   122.42
# policy/loss                                         | -3456.51
# v/loss                                              |  3208.70
# q1/loss                                             | 12152.91
# q2/loss                                             | 11838.13
# policy/grad                                         |     0.00
# v/grad                                              |   995.18
# q1/grad                                             |  -371.43
# q2/grad                                             |  -449.46
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   707.89
# Env/Length/Episode (New)                            |   142.29
# Env/Reward/Episode (Last 50)                        |   653.29
# Env/Length/Episode (Last 50)                        |   131.86
# policy/loss                                         | -3152.79
# v/loss                                              |  5083.40
# q1/loss                                             |  8603.66
# q2/loss                                             | 10049.36
# policy/grad                                         |     0.02
# v/grad                                              |   912.94
# q1/grad                                             |  -181.92
# q2/grad                                             |  -389.05
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |   569.10
# Env/Length/Episode (New)                            |   112.97
# ...
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  5673.73
# Env/Length/Episode (New)                            |  1000.00
# Env/Reward/Episode (Last 50)                        |  5225.17
# Env/Length/Episode (Last 50)                        |   903.98
# policy/loss                                         | -8035.88
# v/loss                                              | 19576.33
# q1/loss                                             | 15407.90
# q2/loss                                             | 10300.14
# policy/grad                                         |     0.05
# v/grad                                              |  -812.65
# q1/grad                                             |  -280.00
# q2/grad                                             |  -221.61
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  5284.78
# Env/Length/Episode (New)                            |   942.00
# Env/Reward/Episode (Last 50)                        |  5236.37
# Env/Length/Episode (Last 50)                        |   909.10
# policy/loss                                         | -8161.66
# v/loss                                              |  8028.51
# q1/loss                                             | 19113.85
# q2/loss                                             | 27551.37
# policy/grad                                         |     0.03
# v/grad                                              | -1973.86
# q1/grad                                             |  1426.44
# q2/grad                                             |  1626.84
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                           |   4099.01
# Env/Length/Episode (New)                           |    698.67
# Env/Reward/Episode (Last 50)                       |   5039.15
# Env/Length/Episode (Last 50)                       |    872.94
# policy/loss                                        |  -7795.44
# v/loss                                             |  38498.91
# q1/loss                                            | 879796.00
# q2/loss                                            | 777616.12
# policy/grad                                        |      0.02
# v/grad                                             |   3598.43
# q1/grad                                            |   3123.21
# q2/grad                                            |   3162.98
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  5887.34
# Env/Length/Episode (New)                            |  1000.00
# Env/Reward/Episode (Last 50)                        |  5046.52
# Env/Length/Episode (Last 50)                        |   872.94
# policy/loss                                         | -7950.29
# v/loss                                              |  3844.54
# q1/loss                                             |  7480.83
# q2/loss                                             |  8610.63
# policy/grad                                         |     0.01
# v/grad                                              |   149.91
# q1/grad                                             |  -815.32
# q2/grad                                             |  -509.95
# --------------------------------------------------------------
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  4614.19
# Env/Length/Episode (New)                            |   791.60
# Env/Reward/Episode (Last 50)                        |  4916.89
# Env/Length/Episode (Last 50)                        |   852.10
# policy/loss                                         | -8197.66
# v/loss                                              |  8437.56
# q1/loss                                             | 14729.13
# q2/loss                                             |  8293.15
# policy/grad                                         |     0.03
# v/grad                                              |  1262.92
# q1/grad                                             |  -805.08
# q2/grad                                             | -1196.58
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  4722.83
# Env/Length/Episode (New)                            |   817.80
# Env/Reward/Episode (Last 50)                        |  4966.46
# Env/Length/Episode (Last 50)                        |   859.54
# policy/loss                                         | -8050.51
# v/loss                                              |  7388.96
# q1/loss                                             | 12613.67
# q2/loss                                             | 12603.08
# policy/grad                                         |    -0.04
# v/grad                                              |  -560.97
# q1/grad                                             |    60.60
# q2/grad                                             |   243.98
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  3815.68
# Env/Length/Episode (New)                            |   674.67
# Env/Reward/Episode (Last 50)                        |  4755.56
# Env/Length/Episode (Last 50)                        |   824.34
# policy/loss                                         | -8064.83
# v/loss                                              |  4621.28
# q1/loss                                             | 10554.38
# q2/loss                                             |  9607.55
# policy/grad                                         |     0.02
# v/grad                                              |  1088.54
# q1/grad                                             |  -880.95
# q2/grad                                             |  -280.05
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  5695.78
# Env/Length/Episode (New)                            |  1000.00
# Env/Reward/Episode (Last 50)                        |  4765.29
# Env/Length/Episode (Last 50)                        |   826.34
# policy/loss                                         | -7966.43
# v/loss                                              |  5095.07
# q1/loss                                             | 13504.41
# q2/loss                                             |  8497.08
# policy/grad                                         |     0.01
# v/grad                                              |  1592.01
# q1/grad                                             | -1580.81
# q2/grad                                             | -1203.92
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  5693.02
# Env/Length/Episode (New)                            |  1000.00
# Env/Reward/Episode (Last 50)                        |  4874.64
# Env/Length/Episode (Last 50)                        |   845.68
# policy/loss                                         | -8110.38
# v/loss                                              | 14947.29
# q1/loss                                             | 16401.96
# q2/loss                                             | 14023.19
# policy/grad                                         |    -0.00
# v/grad                                              | -2905.79
# q1/grad                                             |   844.10
# q2/grad                                             |   854.96
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  3811.81
# Env/Length/Episode (New)                            |   655.67
# Env/Reward/Episode (Last 50)                        |  4832.06
# Env/Length/Episode (Last 50)                        |   839.78
# policy/loss                                         | -8033.68
# v/loss                                              | 10852.27
# q1/loss                                             |  7116.56
# q2/loss                                             |  9594.29
# policy/grad                                         |     0.04
# v/grad                                              | -1632.27
# q1/grad                                             |   474.42
# q2/grad                                             |   989.27
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  5693.83
# Env/Length/Episode (New)                            |   973.00
# Env/Reward/Episode (Last 50)                        |  4826.16
# Env/Length/Episode (Last 50)                        |   837.62
# policy/loss                                         | -8215.31
# v/loss                                              |  3393.65
# q1/loss                                             |  5183.82
# q2/loss                                             |  5342.49
# policy/grad                                         |     0.02
# v/grad                                              | -1025.34
# q1/grad                                             |  -274.59
# q2/grad                                             |   159.48
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  5140.90
# Env/Length/Episode (New)                            |   874.25
# Env/Reward/Episode (Last 50)                        |  4789.55
# Env/Length/Episode (Last 50)                        |   827.56
# policy/loss                                         | -7932.37
# v/loss                                              |  9918.48
# q1/loss                                             | 16914.28
# q2/loss                                             | 26626.84
# policy/grad                                         |    -0.03
# v/grad                                              |  1411.23
# q1/grad                                             | -2153.56
# q2/grad                                             | -3012.98
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  5760.04
# Env/Length/Episode (New)                            |  1000.00
# Env/Reward/Episode (Last 50)                        |  4815.30
# Env/Length/Episode (Last 50)                        |   832.20
# policy/loss                                         | -8128.28
# v/loss                                              | 11174.34
# q1/loss                                             |  8532.58
# q2/loss                                             |  6235.15
# policy/grad                                         |    -0.06
# v/grad                                              | -2394.79
# q1/grad                                             |  -132.68
# q2/grad                                             |  -247.28
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  5340.23
# Env/Length/Episode (New)                            |   919.60
# Env/Reward/Episode (Last 50)                        |  4975.08
# Env/Length/Episode (Last 50)                        |   860.32
# policy/loss                                         | -8119.48
# v/loss                                              |  5337.03
# q1/loss                                             |  7852.28
# q2/loss                                             |  5345.70
# policy/grad                                         |     0.01
# v/grad                                              |  1320.56
# q1/grad                                             |  -674.38
# q2/grad                                             |  -328.66
# --------------------------------------------------------------
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  4411.86
# Env/Length/Episode (New)                            |   771.20
# Env/Reward/Episode (Last 50)                        |  4885.32
# Env/Length/Episode (Last 50)                        |   846.98
# policy/loss                                         | -8003.99
# v/loss                                              |  4958.33
# q1/loss                                             | 17207.22
# q2/loss                                             | 10595.80
# policy/grad                                         |    -0.00
# v/grad                                              |   216.82
# q1/grad                                             |  -255.74
# q2/grad                                             |  -279.51
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  4935.70
# Env/Length/Episode (New)                            |   866.75
# Env/Reward/Episode (Last 50)                        |  4903.00
# Env/Length/Episode (Last 50)                        |   851.90
# policy/loss                                         | -8048.81
# v/loss                                              |  5202.52
# q1/loss                                             | 16876.49
# q2/loss                                             | 13986.78
# policy/grad                                         |     0.01
# v/grad                                              | -1607.26
# q1/grad                                             |  1564.61
# q2/grad                                             |  1663.86
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  4871.43
# Env/Length/Episode (New)                            |   847.60
# Env/Reward/Episode (Last 50)                        |  4892.76
# Env/Length/Episode (Last 50)                        |   850.60
# policy/loss                                         | -8053.23
# v/loss                                              |  4677.32
# q1/loss                                             | 10852.51
# q2/loss                                             | 17899.10
# policy/grad                                         |     0.05
# v/grad                                              |   230.17
# q1/grad                                             |   180.03
# q2/grad                                             |   243.31
# --------------------------------------------------------------
#
# --------------------------------------------------------------
# Env/Reward/Episode (New)                            |  5085.60
# Env/Length/Episode (New)                            |   898.40
# Env/Reward/Episode (Last 50)                        |  5061.87
# Env/Length/Episode (Last 50)                        |   879.48
# policy/loss                                         | -8116.12
# v/loss                                              |  3651.26
# q1/loss                                             |  7505.49
# q2/loss                                             | 17055.56
# policy/grad                                         |     0.02
# v/grad                                              |   108.94
# q1/grad                                             | -1354.16
# q2/grad                                             | -1440.79
# --------------------------------------------------------------
